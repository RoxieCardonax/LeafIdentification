# %% [markdown]
# 1.0. Install Dependencies and Setup

# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (2.12.0)
# Requirement already satisfied: opencv-python in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (4.7.0.72)
# Requirement already satisfied: matplotlib in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (3.7.1)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.9)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.10)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: setuptools in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (66.0.0)
# Requirement already satisfied: packaging in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.18.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: urllib3<2.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.15)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\roxan\anaconda3\envs\classification\lib\site-packages (from scikit-learn) (1.10.1)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       1.4.0
# aiohttp                       3.8.3
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# bcrypt                        3.2.0
# beautifulsoup4                4.12.2
# binaryornot                   0.4.4
# black                         0.0
# bleach                        4.1.0
# bokeh                         2.4.3
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# cachetools                    5.3.0
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.2.1
# colorama                      0.4.6
# colorcet                      3.0.1
# comm                          0.1.2
# constantly                    15.1.0
# contourpy                     1.0.5
# cookiecutter                  1.7.3
# cryptography                  39.0.1
# cssselect                     1.1.0
# cycler                        0.11.0
# cytoolz                       0.12.0
# daal4py                       2023.1.1
# dask                          2023.4.1
# datasets                      2.12.0
# datashader                    0.14.4
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.6
# distributed                   2023.4.1
# docstring-to-markdown         0.11
# docutils                      0.18.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# exceptiongroup                1.0.4
# executing                     0.8.3
# fastjsonschema                2.16.2
# filelock                      3.9.0
# flake8                        6.0.0
# Flask                         2.2.2
# flatbuffers                   23.5.9
# fonttools                     4.25.0
# frozenlist                    1.3.3
# fsspec                        2023.4.0
# future                        0.18.3
# gast                          0.4.0
# gensim                        4.3.0
# google-auth                   2.18.1
# google-auth-oauthlib          1.0.0
# google-pasta                  0.2.0
# greenlet                      2.0.1
# grpcio                        1.54.2
# h5py                          3.7.0
# HeapDict                      1.0.1
# holoviews                     1.15.4
# huggingface-hub               0.14.1
# hvplot                        0.8.2
# hyperlink                     21.0.0
# idna                          3.4
# imagecodecs                   2021.8.26
# imageio                       2.26.0
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# importlib-metadata            6.0.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.8
# intervaltree                  3.1.0
# ipykernel                     6.19.2
# ipython                       8.12.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.4
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jaraco.classes                3.2.1
# jax                           0.4.10
# jedi                          0.18.1
# jellyfish                     0.9.0
# Jinja2                        3.1.2
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.1
# json5                         0.9.6
# jsonschema                    4.17.3
# jupyter                       1.0.0
# jupyter_client                8.1.0
# jupyter-console               6.6.3
# jupyter_core                  5.3.0
# jupyter-server                1.23.4
# jupyterlab                    3.5.3
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.22.0
# jupyterlab-widgets            3.0.5
# keras                         2.12.0
# keyring                       23.13.1
# kiwisolver                    1.4.4
# lazy_loader                   0.1
# lazy-object-proxy             1.6.0
# libclang                      16.0.0
# llvmlite                      0.40.0
# lmdb                          1.4.1
# locket                        1.0.0
# lxml                          4.9.2
# Markdown                      3.4.1
# MarkupSafe                    2.1.1
# matplotlib                    3.7.1
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# menuinst                      1.4.19
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# ml-dtypes                     0.1.0
# mock                          4.0.3
# more-itertools                8.12.0
# mpmath                        1.2.1
# msgpack                       1.0.3
# multidict                     6.0.2
# multipledispatch              0.6.0
# multiprocess                  0.70.14
# munkres                       1.1.4
# mypy-extensions               0.4.3
# nbclassic                     0.5.5
# nbclient                      0.5.13
# nbconvert                     6.5.4
# nbformat                      5.7.0
# nest-asyncio                  1.5.6
# networkx                      2.8.4
# nltk                          3.7
# notebook                      6.5.4
# notebook_shim                 0.2.2
# numba                         0.57.0
# numexpr                       2.8.4
# numpy                         1.23.5
# numpydoc                      1.5.0
# oauthlib                      3.2.2
# opencv-python                 4.7.0.72
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# packaging                     23.0
# pandas                        1.5.3
# pandocfilters                 1.5.0
# panel                         0.14.3
# param                         1.12.3
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.10.3
# patsy                         0.5.3
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           23.0.1
# platformdirs                  2.5.2
# plotly                        5.9.0
# pluggy                        1.0.0
# ply                           3.11
# pooch                         1.4.0
# poyo                          0.5.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.36
# Protego                       0.1.16
# protobuf                      4.23.1
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pyarrow                       11.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.10.0
# pycparser                     2.21
# pyct                          0.5.0
# pycurl                        7.45.2
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pyerfa                        2.0.0
# pyflakes                      3.0.1
# Pygments                      2.15.1
# pylint                        2.16.2
# pylint-venv                   2.3.0
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     23.0.0
# pyparsing                     3.0.9
# PyQt5                         5.15.7
# PyQt5-sip                     12.11.0
# PyQtWebEngine                 5.15.4
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.3.1
# python-dateutil               2.8.2
# python-lsp-black              1.2.1
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.7.2
# python-slugify                5.0.2
# python-snappy                 0.6.1
# pytoolconfig                  1.2.5
# pytz                          2022.7
# pyviz-comms                   2.0.2
# PyWavelets                    1.4.1
# pywin32                       305.1
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.10
# PyYAML                        6.0
# pyzmq                         25.0.2
# QDarkStyle                    3.0.2
# qstylizer                     0.2.2
# QtAwesome                     1.2.2
# qtconsole                     5.4.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# regex                         2022.7.9
# requests                      2.29.0
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# responses                     0.13.3
# rope                          1.7.0
# rsa                           4.9
# Rtree                         1.0.1
# sacremoses                    0.0.43
# scikit-image                  0.20.0
# scikit-learn                  1.2.2
# scikit-learn-intelex          20230426.121158
# scipy                         1.10.1
# Scrapy                        2.8.0
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    66.0.0
# sip                           6.6.2
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.4
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.4.3
# spyder-kernels                2.4.3
# SQLAlchemy                    1.4.39
# stack-data                    0.2.0
# statsmodels                   0.13.5
# sympy                         1.11.1
# tables                        3.7.0
# tabulate                      0.8.10
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.12.3
# tensorboard-data-server       0.7.0
# tensorflow                    2.12.0
# tensorflow-estimator          2.12.0
# tensorflow-intel              2.12.0
# tensorflow-io-gcs-filesystem  0.31.0
# termcolor                     2.3.0
# terminado                     0.17.1
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss2                      1.2.1
# tldextract                    3.2.0
# tokenizers                    0.11.4
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.12.0
# torch                         1.12.1
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.7.1
# transformers                  4.29.2
# Twisted                       22.10.0
# twisted-iocpsupport           1.0.2
# typing_extensions             4.5.0
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       1.26.15
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.2.3
# whatthepatch                  1.0.2
# wheel                         0.38.4
# widgetsnbextension            4.0.5
# win-inet-pton                 1.1.0
# wrapt                         1.14.1
# xarray                        2022.11.0
# xlwings                       0.29.1
# xxhash                        2.0.2
# yapf                          0.31.0
# yarl                          1.8.1
# zict                          2.2.0
# zipp                          3.11.0
# zope.interface                5.4.0

# %%
import tensorflow as tf
import os

# %%
#Only use 50% of GPU
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# 1.1. Remove Dodgy Image

# %%
import cv2
import imghdr # allows to check file extensions 
from matplotlib import pyplot as plt

# %%
data_dir = 'smalldata' #variable to hold path to data directory

# %%
image_extensions = ['jpeg','jpg', 'bmp', 'png'] #list of standard image file extensions

# %%
# for loop - looping through directory and then every image to check if they can be used by cv2 and imghdr if not then they are removed
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path) #not a valid image
            tip = imghdr.what(image_path) #not a valid image extension
            if tip not in image_extensions: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %%
#How many classes are there?
num_classes = 0

#Iterate Directory
for path in os.listdir(data_dir):
    num_classes += 1
print ('File count:', num_classes)
# Out:
# File count: 2

# %% [markdown]
# 2.0. Load Data

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#Build the data pipeline
data = tf.keras.utils.image_dataset_from_directory('smalldata')
# Out:
# Found 100 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator() #access the generator from data pipeline - allowing us to loop through data pipeline

# %%
batch = data_iterator.next() #accessing the data piepline itself

# %%
# for loop - looping through the images and classifying them as healthy = 0 and unhealthy = 1
#shows the classifications 0=healthy, 1 = unhealthy
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# 3.0. Pre-Processing Data

# %% [markdown]
# 3.1. Scale Data

# %%
data = data.map(lambda x,y: (x/255, y)) #map - applies a particular transformation as data is being preprocessed by the data pipeline... x = images, y = target values

# %%
scaled_iterator=data.as_numpy_iterator()

# %%
batch = scaled_iterator.next()

# %%
#CHECK FOR BATCH MAX AND MIN 0 - 1
#batch [0].min()
batch [0].max()
# Out:
# 0.89522827

# %%
#CHECK IF IMAGES ARE LOADED AND SCALED
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])
    #shows the classifications healthy = 0 and unhealthy = 1

# %% [markdown]
# 3.2. Split Data

# %%
#Partitian Allocation
train_size = int(len(data)*.7) #training will be 70% of data
val_size = int(len(data)*.2) #20% for validation
test_size = int(len(data)*.1+1) #10% testing + 1 because the data is an uneven number

# %%
#CHECK that it is equal to length
train_size+val_size+test_size
# Out:
# 3

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# 4.0. Deep Learning Model

# %% [markdown]
# 4.1. Build CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.regularizers import l2

# %%
model = Sequential()

# %%
#Adding layers sequestially
#16 = Number of filters
#3,3 = Size of filter
#1 Stride (one pixel and then moves onto the next pixel)
#activitation that gets applied - relu activation - taking the output from the convolution layer and passing it through the relu function - preserve the positive values - allows us to take into account the non linear values 
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D()) #condenses the data down

model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu')) #fully connected layers
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss='squared_hinge', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 14400)             0
#
#  dense_2 (Dense)             (None, 256)               3686656
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4.2. Build SVM Mode.

# %% [markdown]
# 4.2. Train

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val) #fit is the training function
# Out:
# Epoch 1/20
# 2/2 [==============================] - 5s 596ms/step - loss: 1.0000 - accuracy: 0.4844
# Epoch 2/20
# 2/2 [==============================] - 3s 613ms/step - loss: 1.0000 - accuracy: 0.4844
# Epoch 3/20
# 2/2 [==============================] - 3s 610ms/step - loss: 1.0000 - accuracy: 0.5312
# Epoch 4/20
# 2/2 [==============================] - 3s 673ms/step - loss: 1.0000 - accuracy: 0.5469
# Epoch 5/20
# 2/2 [==============================] - 4s 703ms/step - loss: 1.0000 - accuracy: 0.5312
# Epoch 6/20
# 2/2 [==============================] - 3s 668ms/step - loss: 1.0000 - accuracy: 0.4688
# Epoch 7/20
# 2/2 [==============================] - 4s 617ms/step - loss: 1.0000 - accuracy: 0.4844
# Epoch 8/20
# 2/2 [==============================] - 4s 630ms/step - loss: 1.0000 - accuracy: 0.5000
# Epoch 9/20
# 2/2 [==============================] - 4s 690ms/step - loss: 1.0000 - accuracy: 0.5156
# Epoch 10/20
# 2/2 [==============================] - 4s 684ms/step - loss: 1.0000 - accuracy: 0.5469
# Epoch 11/20
# 2/2 [==============================] - 3s 594ms/step - loss: 1.0000 - accuracy: 0.5000
# Epoch 12/20
# 2/2 [==============================] - 3s 666ms/step - loss: 1.0000 - accuracy: 0.4844
# Epoch 13/20
# 2/2 [==============================] - 3s 614ms/step - loss: 1.0000 - accuracy: 0.5625
# Epoch 14/20
# 2/2 [==============================] - 3s 646ms/step - loss: 1.0000 - accuracy: 0.5938
# Epoch 15/20
# 2/2 [==============================] - 3s 652ms/step - loss: 1.0000 - accuracy: 0.5156
# Epoch 16/20
# 2/2 [==============================] - 3s 622ms/step - loss: 1.0000 - accuracy: 0.4531
# Epoch 17/20
# 2/2 [==============================] - 3s 594ms/step - loss: 1.0000 - accuracy: 0.5469
# Epoch 18/20
# 2/2 [==============================] - 3s 640ms/step - loss: 1.0000 - accuracy: 0.6094
# Epoch 19/20
# 2/2 [==============================] - 3s 676ms/step - loss: 1.0000 - accuracy: 0.4844
# Epoch 20/20
# 2/2 [==============================] - 3s 635ms/step - loss: 1.0000 - accuracy: 0.4688

# %% [markdown]
# 4.3. Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 3
#       1 fig = plt.figure()
#       2 plt.plot(hist.history['loss'], color='teal', label='loss')
# ----> 3 plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
#       4 fig.suptitle('Loss', fontsize=20)
#       5 plt.legend(loc="upper left")
#
# KeyError: 'val_loss'

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# 5.0 Evaluate

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)

# %%
print(f'Precision:{pre.result().numpy()}, Recall:{re.result().numpy()}, Accuracy: {acc.result().numpy()}')

# %% [markdown]
# 6.0 Test

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('healthy_test.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))

# %%
yhat

# %%
if yhat > 0.5: 
    print(f'Predicted class is Unhealthy')
else:
    print(f'Predicted class is Healthy')

# %% [markdown]
# 8.0 Save Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','CNN.h5'))

# %%
new_model = load_model('CNN.h5')

# %%
new_model.predict(np.expand_dims(resize/255, 0))
